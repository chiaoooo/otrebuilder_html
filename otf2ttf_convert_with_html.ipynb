# %% [markdown]
# <a href="https://colab.research.google.com/github/chiaoooo/otrebuilder_html/blob/main/otf2ttf_convert_with_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Download the Dependencies from github.
# 2. Change dirctory to otRebuilder directory and install the library with pip.
# 3. Mount your Google Drive to Google Colab.
# 4. List your files in Google Drive
# 5. Start conversion otf->ttf
# 6. Start conversion ttf->otf
# 7. download file

# %%
from google.colab import output
import json, os

# Download the otRebuilder library
def download_dependencies():
  # !git clone https://github.com/t109598105/otRebuilder.git

  return

# Install otRebuilder via pip
def install_dependencies():
  # %cd otRebuilder
  # !pip3 install .

  return

# Mount your google drive to the colab VM
def mount_google_drive():
  from google.colab import drive
  drive.mount('/content/gdrive', force_remount=True)

  return

# List your otf/ttf files in your google drive
def list_files():
  otf_files = [f for f in os.listdir('/content/gdrive/MyDrive/otf_fonts') if f.split('.')[-1] == 'otf']
  ttf_files = [f for f in os.listdir('/content/gdrive/MyDrive/otf_fonts') if f.split('.')[-1] == 'ttf']

  return json.dumps({'otf_files': otf_files, 'ttf_files': ttf_files}, ensure_ascii=False)

# Convert otf to ttf
def otf_to_ttf(otf_file):
  otf_path = os.path.join(os.sep, 'content', 'gdrive', 'MyDrive', 'otf_fonts', otf_file)
  ttf_path = os.path.join(os.sep, 'content', 'gdrive', 'MyDrive', 'otf_fonts', ''.join(otf_file.split('.')[:-1]+['.ttf']))

  # !echo "otrebuild --otf2ttf --UPM 2048 --removeGlyphNames --O1 -o \"$ttf_path\" \"$otf_path\"" | bash

  return

# Convert ttf to otf
def ttf_to_otf(ttf_file):
  otf_path = os.path.join(os.sep, 'content', 'gdrive', 'MyDrive', 'otf_fonts', ''.join(ttf_file.split('.')[:-1]+['.otf']))
  ttf_path = os.path.join(os.sep, 'content', 'gdrive', 'MyDrive', 'otf_fonts', ttf_file)

  # !echo "otrebuild --UPM 2048 --removeGlyphNames --O1 -o \"$otf_path\" \"$ttf_path\"" | bash

  return

# Register functions
funcs = [download_dependencies, install_dependencies, mount_google_drive, list_files, otf_to_ttf, ttf_to_otf]

for func in funcs:
  output.register_callback(func.__name__, func)

# %% [markdown]
# HTML Interface

# %%
# %%html
# <html><head> <meta charset="utf-8"> <style>@import url(https://fonts.googleapis.com/css2?family=Roboto:wght@300&display=swap);*{padding:0;margin:0;box-sizing:border-box}body{font-family:Roboto,sans-serif;background-image:url(https://images.pexels.com/photos/1166644/pexels-photo-1166644.jpeg?cs=srgb&dl=pexels-andreea-ch-1166644.jpg&fm=jpg);background-attachment:fixed;background-position:center;background-size:cover}.main{height:100vh;width:100vw;padding:0 30px}.btn{padding:5px 20px;color:#fff;background-color:#3838db;cursor:pointer;border-style:solid;border-color:#000;border-width:1px;display:inline-block}.main .head{font-size:60px;text-align:center;padding:30px 0;border-bottom-style:solid;font-weight:700}.main .step{text-align:center;padding-top:50px}.main .step .inner{display:inline-block;margin:auto;width:50%}.main .step .step-title{font-size:30px;text-align:left}.main .step .step-operation{padding-top:20px;text-align:right;font-size:25px}.main .step .step-info{padding-top:20px}.main .convert{text-align:center;padding-top:50px}.main .convert .title{font-size:35px;margin-bottom:20px}.main .convert select{font-size:25px;padding:5px;cursor:pointer}.stream{display:none!important}</style></head><body> <div class="main"> <div class="head"> OTF TTF Converter </div><div class="step"> <div class="inner"> <div class="step-title"> Step_<span id="step-order"></span>: <span id="step-title"> </span> </div><div class="step-operation"> <div class="btn" id="step-btn"></div></div><div class="step-info" id="step-info"> </div></div></div><div class="convert" style="display: none"> <div class="title"> Select Font File: </div><select id="dropdown-list"> <option value="select"> Select </option> </select> <div style="margin-top:20px;" id="convert_info"></div></div></div><script src="https://d3js.org/d3.v4.min.js"></script> <script>var pyExecute=function(t,e,n){window.google.colab.kernel.invokeFunction(t,e).then(function(t){"function"==typeof n&&n(t)})},isBusy=!1,font_files_list=null,currentStep=0,steps=[{title:"Download Dependencies",btnText:"Download",info:"Downloading dependencies, please wait...",onclick:function(){isBusy||(d3.select("#step-info").style("display","block"),isBusy=!0,pyExecute("download_dependencies",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Install Dependencies",btnText:"Install",info:"Installing dependencies, please wait...",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("install_dependencies",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Mount Google Drive",btnText:"Mount",info:"Mounting google drive, please confirm the pop-up window...",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("mount_google_drive",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Get font files",btnText:"Get",info:"Get font files",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("list_files",[],function(t){isBusy=!1,d3.select(".step").style("display","none"),d3.select(".convert").style("display","block"),null===font_files_list&&(font_files_list=JSON.parse(t.data["text/plain"].replace(/^'|'$/g,"")));var e=font_files_list.otf_files.map(function(t){return{type:"otf",name:t}}).concat(font_files_list.ttf_files.map(function(t){return{type:"ttf",name:t}})),t=d3.select("#dropdown-list");t.selectAll("option").data([{}].concat(e)).enter().append("option").attr("value",function(t){return t.type+"_"+t.name}).text(function(t){return t.name}),console.log(t),t.on("change",function(){var t,e;isBusy||(1==(t=this.value.split("_")).length&&"select"==t[0]||(isBusy=!0,e={ttf:{convert:function(t,e){pyExecute("ttf_to_otf",[t],e)},toString:function(){return"otf"}},otf:{convert:function(t,e){pyExecute("otf_to_ttf",[t],e)},toString:function(){return"ttf"}}},d3.select("#convert_info").text("Converting: "+t[1]+" to "+e[t[0]].toString()+", please wait..."),e[t[0]].convert(t[1],function(){d3.select("#convert_info").text("File: "+t[1]+" converted"),isBusy=!1})))})}))}}];function nextStep(){var t=steps[currentStep];d3.select("#step-info").style("display","none"),d3.select("#step-order").text(currentStep+1),d3.select("#step-title").text(t.title),d3.select("#step-btn").on("click",null),d3.select("#step-btn").text(t.btnText),d3.select("#step-btn").on("click",t.onclick),d3.select("#step-info").text(t.info)}nextStep(); </script></body></html>
# Out:
# <html><head> <meta charset="utf-8"> <style>@import url(https://fonts.googleapis.com/css2?family=Roboto:wght@300&display=swap);*{padding:0;margin:0;box-sizing:border-box}body{font-family:Roboto,sans-serif;background-image:url(https://images.pexels.com/photos/1166644/pexels-photo-1166644.jpeg?cs=srgb&dl=pexels-andreea-ch-1166644.jpg&fm=jpg);background-attachment:fixed;background-position:center;background-size:cover}.main{height:100vh;width:100vw;padding:0 30px}.btn{padding:5px 20px;color:#fff;background-color:#3838db;cursor:pointer;border-style:solid;border-color:#000;border-width:1px;display:inline-block}.main .head{font-size:60px;text-align:center;padding:30px 0;border-bottom-style:solid;font-weight:700}.main .step{text-align:center;padding-top:50px}.main .step .inner{display:inline-block;margin:auto;width:50%}.main .step .step-title{font-size:30px;text-align:left}.main .step .step-operation{padding-top:20px;text-align:right;font-size:25px}.main .step .step-info{padding-top:20px}.main .convert{text-align:center;padding-top:50px}.main .convert .title{font-size:35px;margin-bottom:20px}.main .convert select{font-size:25px;padding:5px;cursor:pointer}.stream{display:none!important}</style></head><body> <div class="main"> <div class="head"> OTF TTF Converter </div><div class="step"> <div class="inner"> <div class="step-title"> Step_<span id="step-order"></span>: <span id="step-title"> </span> </div><div class="step-operation"> <div class="btn" id="step-btn"></div></div><div class="step-info" id="step-info"> </div></div></div><div class="convert" style="display: none"> <div class="title"> Select Font File: </div><select id="dropdown-list"> <option value="select"> Select </option> </select> <div style="margin-top:20px;" id="convert_info"></div></div></div><script src="https://d3js.org/d3.v4.min.js"></script> <script>var pyExecute=function(t,e,n){window.google.colab.kernel.invokeFunction(t,e).then(function(t){"function"==typeof n&&n(t)})},isBusy=!1,font_files_list=null,currentStep=0,steps=[{title:"Download Dependencies",btnText:"Download",info:"Downloading dependencies, please wait...",onclick:function(){isBusy||(d3.select("#step-info").style("display","block"),isBusy=!0,pyExecute("download_dependencies",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Install Dependencies",btnText:"Install",info:"Installing dependencies, please wait...",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("install_dependencies",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Mount Google Drive",btnText:"Mount",info:"Mounting google drive, please confirm the pop-up window...",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("mount_google_drive",[],function(){isBusy=!1,currentStep++,nextStep()}))}},{title:"Get font files",btnText:"Get",info:"Get font files",onclick:function(){isBusy||(isBusy=!0,d3.select("#step-info").style("display","block"),pyExecute("list_files",[],function(t){isBusy=!1,d3.select(".step").style("display","none"),d3.select(".convert").style("display","block"),null===font_files_list&&(font_files_list=JSON.parse(t.data["text/plain"].replace(/^'|'$/g,"")));var e=font_files_list.otf_files.map(function(t){return{type:"otf",name:t}}).concat(font_files_list.ttf_files.map(function(t){return{type:"ttf",name:t}})),t=d3.select("#dropdown-list");t.selectAll("option").data([{}].concat(e)).enter().append("option").attr("value",function(t){return t.type+"_"+t.name}).text(function(t){return t.name}),console.log(t),t.on("change",function(){var t,e;isBusy||(1==(t=this.value.split("_")).length&&"select"==t[0]||(isBusy=!0,e={ttf:{convert:function(t,e){pyExecute("ttf_to_otf",[t],e)},toString:function(){return"otf"}},otf:{convert:function(t,e){pyExecute("otf_to_ttf",[t],e)},toString:function(){return"ttf"}}},d3.select("#convert_info").text("Converting: "+t[1]+" to "+e[t[0]].toString()+", please wait..."),e[t[0]].convert(t[1],function(){d3 ...
# Cloning into 'otRebuilder'...
# remote: Enumerating objects: 1053, done.
# remote: Total 1053 (delta 0), reused 0 (delta 0), pack-reused 1053
# Receiving objects: 100% (1053/1053), 10.40 MiB | 37.23 MiB/s, done.
# Resolving deltas: 100% (525/525), done.
# /content/otRebuilder
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/otRebuilder
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from otrebuilder==1.5.6) (0.10.2)
# Collecting fonttools
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 41.4 MB/s eta 0:00:00
# Collecting cu2qu
#   Downloading cu2qu-1.6.7.post2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (464 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.9/464.9 KB 38.2 MB/s eta 0:00:00
# Collecting ufoLib
#   Downloading ufoLib-2.3.2-py2.py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 KB 9.6 MB/s eta 0:00:00
# Collecting fonttools
#   Downloading fonttools-3.44.0-py2.py3-none-any.whl (728 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.0/728.0 KB 61.2 MB/s eta 0:00:00
# Collecting fonttools[ufo]>=3.32.0
#   Downloading fonttools-4.37.4-py3-none-any.whl (960 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.8/960.8 KB 32.6 MB/s eta 0:00:00
#   Downloading fonttools-4.37.3-py3-none-any.whl (959 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.0/960.0 KB 50.1 MB/s eta 0:00:00
#   Downloading fonttools-4.37.2-py3-none-any.whl (959 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 KB 66.3 MB/s eta 0:00:00
#   Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 957.2/957.2 KB 68.5 MB/s eta 0:00:00
#   Downloading fonttools-4.37.0-py3-none-any.whl (956 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.5/956.5 KB 57.2 MB/s eta 0:00:00
#   Downloading fonttools-4.36.0-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.4/950.4 KB 70.9 MB/s eta 0:00:00
#   Downloading fonttools-4.35.0-py3-none-any.whl (947 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 947.1/947.1 KB 66.7 MB/s eta 0:00:00
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 KB 68.6 MB/s eta 0:00:00
#   Downloading fonttools-4.34.3-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 KB 72.5 MB/s eta 0:00:00
#   Downloading fonttools-4.34.2-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.0/944.0 KB 71.4 MB/s eta 0:00:00
#   Downloading fonttools-4.34.1-py3-none-any.whl (943 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.9/943.9 KB 71.3 MB/s eta 0:00:00
#   Downloading fonttools-4.34.0-py3-none-any.whl (943 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.8/943.8 KB 68.8 MB/s eta 0:00:00
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 KB 55.8 MB/s eta 0:00:00
#   Downloading fonttools-4.33.2-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.7/930.7 KB 68.6 MB/s eta 0:00:00
#   Downloading fonttools-4.33.1-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.5/930.5 KB 61.8 MB/s eta 0:00:00
#   Downloading fonttools-4.33.0-py3-none-any.whl (929 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.9/929.9 KB 45.5 MB/s eta 0:00:00
#   Downloading fonttools-4.32.0-py3-none-any.whl (900 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 900.8/900.8 KB 55.1 MB/s eta 0:00:00
#   Downloading fonttools-4.31.2-py3-none-any.whl (899 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.5/899.5 KB 56.8 MB/s eta 0:00:00
#   Downloading fonttools-4.31.1-py3-none-any.whl (899 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.4/899.4 KB 54.9 MB/s eta 0:00:00
#   Downloading fonttools-4.31.0-py3-none-any.whl (899 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.3/899.3 KB 56.3 MB/s eta 0:00:00
#   Downloading fonttools-4.30.0-py3-none-any.whl (898 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.1/898.1 KB 47.5 MB/s eta 0:00:00
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.5/895.5 KB 58.4 MB/s eta 0:00:00
#   Downloading fonttools-4.29.0-py3-none-any.whl (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.0/895.0 KB 56.3 MB/s eta 0:00:00
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.4/890.4 KB 47.1 MB/s eta 0:00:00
#   Downloading fonttools-4.28.4-py3-none-any.whl (885 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.2/885.2 KB 59.1 MB/s eta 0:00:00
#   Downloading fonttools-4.28.3-py3-none-any.whl (884 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 884.2/884.2 KB 26.8 MB/s eta 0:00:00
#   Downloading fonttools-4.28.2-py3-none-any.whl (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.4/880.4 KB 51.2 MB/s eta 0:00:00
#   Downloading fonttools-4.28.1-py3-none-any.whl (873 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 KB 35.4 MB/s eta 0:00:00
#   Downloading fonttools-4.28.0-py3-none-any.whl (873 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.4/873.4 KB 39.6 MB/s eta 0:00:00
#   Downloading fonttools-4.27.1-py3-none-any.whl (869 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.8/869.8 KB 6.7 MB/s eta 0:00:00
#   Downloading fonttools-4.27.0-py3-none-any.whl (869 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.5/869.5 KB 3.3 MB/s eta 0:00:00
#   Downloading fonttools-4.26.2-py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.5/870.5 KB 12.9 MB/s eta 0:00:00
#   Downloading fonttools-4.26.1-py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.4/870.4 KB 57.5 MB/s eta 0:00:00
#   Downloading fonttools-4.26.0-py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.2/870.2 KB 56.6 MB/s eta 0:00:00
#   Downloading fonttools-4.25.2-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.3/868.3 KB 55.5 MB/s eta 0:00:00
#   Downloading fonttools-4.25.1-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.1/868.1 KB 51.6 MB/s eta 0:00:00
#   Downloading fonttools-4.25.0-py3-none-any.whl (867 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.9/867.9 KB 56.8 MB/s eta 0:00:00
#   Downloading fonttools-4.24.4-py3-none-any.whl (854 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.9/854.9 KB 69.3 MB/s eta 0:00:00
#   Downloading fonttools-4.24.3-py3-none-any.whl (854 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.8/854.8 KB 66.8 MB/s eta 0:00:00
#   Downloading fonttools-4.24.2-py3-none-any.whl (853 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.9/853.9 KB 67.8 MB/s eta 0:00:00
#   Downloading fonttools-4.24.1-py3-none-any.whl (853 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.9/853.9 KB 74.2 MB/s eta 0:00:00
#   Downloading fonttools-4.24.0-py3-none-any.whl (853 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.8/853.8 KB 72.7 MB/s eta 0:00:00
#   Downloading fonttools-4.23.1-py3-none-any.whl (853 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.1/853.1 KB 73.5 MB/s eta 0:00:00
#   Downloading fonttools-4.23.0-py3-none-any.whl (852 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.0/853.0 KB 59.3 MB/s eta 0:00:00
#   Downloading fonttools-4.22.1-py3-none-any.whl (850 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 850.2/850.2 KB 65.7 MB/s eta 0:00:00
#   Downloading fonttools-4.22.0-py3-none-any.whl (850 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 850.6/850.6 KB 70.2 MB/s eta 0:00:00
#   Downloading fonttools-4.21.1-py3-none-any.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 KB 61.5 MB/s eta 0:00:00
#   Downloading fonttools-4.21.0-py3-none-any.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.8/849.8 KB 64.0 MB/s eta 0:00:00
#   Downloading fonttools-4.20.0-py3-none-any.whl (838 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.5/838.5 KB 67.6 MB/s eta 0:00:00
#   Downloading fonttools-4.19.1-py3-none-any.whl (832 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.8/832.8 KB 64.4 MB/s eta 0:00:00
#   Downloading fonttools-4.19.0-py3-none-any.whl (832 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.8/832.8 KB 69.6 MB/s eta 0:00:00
#   Downloading fonttools-4.18.2-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.0/829.0 KB 70.9 MB/s eta 0:00:00
#   Downloading fonttools-4.18.1-py3-none-any.whl (828 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.9/828.9 KB 68.0 MB/s eta 0:00:00
#   Downloading fonttools-4.18.0-py3-none-any.whl (828 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.6/828.6 KB 5.0 MB/s eta 0:00:00
#   Downloading fonttools-4.17.1-py3-none-any.whl (824 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.4/824.4 KB 61.6 MB/s eta 0:00:00
#   Downloading fonttools-4.17.0-py3-none-any.whl (824 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.1/824.1 KB 68.5 MB/s eta 0:00:00
#   Downloading fonttools-4.16.1-py3-none-any.whl (818 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.7/818.7 KB 68.8 MB/s eta 0:00:00
#   Downloading fonttools-4.16.0-py3-none-any.whl (818 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.5/818.5 KB 68.9 MB/s eta 0:00:00
#   Downloading fonttools-4.15.0-py3-none-any.whl (815 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.5/815.5 KB 69.1 MB/s eta 0:00:00
#   Downloading fonttools-4.14.0-py3-none-any.whl (811 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.7/811.7 KB 62.0 MB/s eta 0:00:00
#   Downloading fonttools-4.13.0-py3-none-any.whl (810 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.2/810.2 KB 74.5 MB/s eta 0:00:00
#   Downloading fonttools-4.12.1-py3-none-any.whl (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 KB 61.4 MB/s eta 0:00:00
#   Downloading fonttools-4.12.0-py3-none-any.whl (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 KB 68.4 MB/s eta 0:00:00
#   Downloading fonttools-4.11.0-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.4/798.4 KB 63.0 MB/s eta 0:00:00
#   Downloading fonttools-4.10.2-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.9/797.9 KB 69.1 MB/s eta 0:00:00
#   Downloading fonttools-4.10.1-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.8/797.8 KB 58.4 MB/s eta 0:00:00
#   Downloading fonttools-4.10.0-py3-none-any.whl (795 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.3/795.3 KB 64.4 MB/s eta 0:00:00
#   Downloading fonttools-4.9.0-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.2/780.2 KB 66.6 MB/s eta 0:00:00
#   Downloading fonttools-4.8.1-py3-none-any.whl (755 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 KB 64.0 MB/s eta 0:00:00
#   Downloading fonttools-4.8.0-py3-none-any.whl (755 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 KB 66.4 MB/s eta 0:00:00
#   Downloading fonttools-4.7.0-py3-none-any.whl (749 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.3/749.3 KB 61.1 MB/s eta 0:00:00
#   Downloading fonttools-4.6.0-py3-none-any.whl (734 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.2/734.2 KB 69.8 MB/s eta 0:00:00
#   Downloading fonttools-4.5.0-py3-none-any.whl (734 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.1/734.1 KB 63.3 MB/s eta 0:00:00
#   Downloading fonttools-4.4.3-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 KB 60.4 MB/s eta 0:00:00
#   Downloading fonttools-4.4.2-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 KB 61.7 MB/s eta 0:00:00
#   Downloading fonttools-4.4.1-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.4/732.4 KB 66.4 MB/s eta 0:00:00
#   Downloading fonttools-4.4.0-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.1/732.1 KB 55.3 MB/s eta 0:00:00
#   Downloading fonttools-4.3.0-py3-none-any.whl (727 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.0/727.0 KB 59.0 MB/s eta 0:00:00
#   Downloading fonttools-4.2.5-py3-none-any.whl (726 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.3/726.3 KB 63.9 MB/s eta 0:00:00
#   Downloading fonttools-4.2.4-py3-none-any.whl (726 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.1/726.1 KB 60.4 MB/s eta 0:00:00
#   Downloading fonttools-4.2.3-py3-none-any.whl (726 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.0/726.0 KB 63.4 MB/s eta 0:00:00
#   Downloading fonttools-4.2.2-py3-none-any.whl (725 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.7/725.7 KB 67.3 MB/s eta 0:00:00
#   Downloading fonttools-4.2.1-py3-none-any.whl (725 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.3/725.3 KB 65.1 MB/s eta 0:00:00
#   Downloading fonttools-4.2.0-py3-none-any.whl (725 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.2/725.2 KB 49.3 MB/s eta 0:00:00
#   Downloading fonttools-4.1.0-py3-none-any.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.9/722.9 KB 57.5 MB/s eta 0:00:00
#   Downloading fonttools-4.0.2-py3-none-any.whl (717 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.1/717.1 KB 65.0 MB/s eta 0:00:00
#   Downloading fonttools-4.0.1-py3-none-any.whl (717 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.6/717.6 KB 64.2 MB/s eta 0:00:00
#   Downloading fonttools-4.0.0-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.7/716.7 KB 60.8 MB/s eta 0:00:00
# Collecting fs<3,>=2.2.0
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 KB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.8/dist-packages (from fs<3,>=2.2.0->fonttools->otrebuilder==1.5.6) (1.4.4)
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.8/dist-packages (from fs<3,>=2.2.0->fonttools->otrebuilder==1.5.6) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fs<3,>=2.2.0->fonttools->otrebuilder==1.5.6) (57.4.0)
# Building wheels for collected packages: otrebuilder
#   Building wheel for otrebuilder (setup.py) ... done
#   Created wheel for otrebuilder: filename=otrebuilder-1.5.6-py3-none-any.whl size=41640 sha256=4d5f774803260c88b0d4fec6e6bf2fad70d248c91ebec8d8d65f787a426c56cb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yv7up7ql/wheels/4d/21/6f/7552c4639d0c0d169614a2b4e0af280711c74039fea9e98724
# Successfully built otrebuilder
# Installing collected packages: fonttools, ufoLib, fs, cu2qu, otrebuilder
# Successfully installed cu2qu-1.6.7.post2 fonttools-3.44.0 fs-2.4.16 otrebuilder-1.5.6 ufoLib-2.3.2
# Mounted at /content/gdrive
# Input Font: /content/gdrive/MyDrive/otf_fonts/SourceHanSerif-Heavy.otf
# Processing...
# Done.
# Output Font: /content/gdrive/MyDrive/otf_fonts/SourceHanSerif-Heavy#1.ttf
